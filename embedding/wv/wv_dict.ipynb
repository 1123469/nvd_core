# %%
from gensim.models import word2vec  # 导入gensim包
years = ['2002','2003','2004','2005','2006','2007','2008','2009','2010','2011','2012','2013','2014','2015','2016','2017','2018','2019','2020','2021','2022']
infix = ''
infix = str(years[0])+"to"+str(years[len(years)-1])
infix+='_no'

cwe_min_count = 3000


infix+='_'+str(cwe_min_count)

wv_model_path  = '..//..//models//wv//'+infix+"_"+str(vec_len)+"_"+str(min_count)+"_"+str(window_len)+'.pkl'
wv_model = word2vec.Word2Vec.load(wv_model_path)

# %%
print(wv_model)
wv_model.wv['buffer']
# Out:
# Word2Vec(vocab=56396, vector_size=100, alpha=0.025)
# array([-0.25341958, -1.5283091 , -2.4111252 , -1.4178834 , -0.6192789 ,
#        -2.0714133 , -1.5703521 , -0.23351257,  0.61168545,  1.6136642 ,
#        -1.81431   ,  1.7253432 ,  2.7079127 ,  0.9516144 , -2.368903  ,
#         4.242641  ,  1.3644367 ,  0.93686765, -1.9764469 , -0.7124215 ,
#        -1.8632411 ,  0.29637834, -0.7543641 , -0.6505928 ,  0.6589405 ,
#        -0.05169562,  1.136389  ,  0.6761623 ,  0.85164165, -0.82880604,
#        -0.1644576 ,  2.165653  ,  1.1839308 ,  1.1128742 ,  1.8147123 ,
#         0.22388233,  0.2255759 , -3.5487804 ,  1.2207663 ,  1.5833465 ,
#        -3.2677643 ,  0.11666566, -0.80467266, -0.54382485,  2.6525319 ,
#        -1.7723366 ,  3.4895823 , -1.3108242 , -0.9058661 , -2.645296  ,
#         2.2463138 , -0.7891669 , -2.1810193 ,  1.5269263 ,  2.326256  ,
#         1.7499456 , -0.34832612,  2.157901  ,  0.347776  ,  2.3488631 ,
#         0.07099795,  2.0634832 ,  1.4132339 , -1.2676413 ,  0.25886428,
#         2.235496  , -1.3110583 , -2.925725  ,  0.3713242 ,  3.2108624 ,
#        -0.03895131, -1.7870274 ,  1.3509296 , -0.00752639, -2.5903153 ,
#        -1.1652366 ,  0.3983184 ,  0.40334567, -1.0630434 ,  2.5999432 ,
#        -1.7351762 ,  1.1793319 ,  0.33128566,  1.4498719 , -0.27981317,
#        -0.5813962 , -1.7002305 ,  1.2504086 ,  4.0087976 ,  1.0150317 ,
#         1.387371  ,  1.5926595 , -0.9672869 ,  2.2487562 , -1.553164  ,
#        -3.900477  ,  1.7607164 ,  0.54485184,  2.056395  , -1.0264335 ],
#       dtype=float32)

# %%
from gensim.models import fasttext  # 导入gensim包
years = ['2002','2003','2004','2005','2006','2007','2008','2009','2010','2011','2012','2013','2014','2015','2016','2017','2018','2019','2020','2021','2022']
infix = ''
infix = str(years[0])+"to"+str(years[len(years)-1])
# 标记
infix+='_no'
# cwe_min_count = 500
# cwe_min_count = 700
# cwe_min_count = 2000
cwe_min_count = 2500
# cwe_min_count = 3000
infix+='_'+str(cwe_min_count)
vec_len = 100
# vec_len = 200
# vec_len = 300
min_count = 1
window_len = 5
dense_unit = 128
fast_model_path  = '..//..//models//fasttext//'+infix+"_"+str(vec_len)+"_"+str(min_count)+"_"+str(window_len)+'.pkl'

# %%
fast_model = fasttext.FastText.load(fast_model_path)
print(fast_model)
fast_model.wv['ip']
# Out:
# FastText(vocab=62622, vector_size=100, alpha=0.025)
# array([-0.5378374 ,  0.5806179 ,  0.32222256,  0.05787673,  0.31434506,
#         0.05999523,  0.28081334,  0.17478868,  0.09197029, -0.02579409,
#         0.21428898, -0.2655426 ,  0.03907695,  0.2574336 , -0.16727243,
#        -0.11378405,  0.24191973, -0.22064927,  0.02795213, -0.25663176,
#         0.28543925,  0.14225127, -0.00886354,  0.16031082,  0.17709954,
#         0.07345951,  0.08142629,  0.07658508, -0.2956947 , -0.24838169,
#         0.18096335, -0.09793832,  0.19434872, -0.2253934 , -0.22742397,
#        -0.2890072 ,  0.1051659 ,  0.21747479,  0.08580822, -0.01106345,
#         0.03447437,  0.29286912,  0.07822357, -0.46553725, -0.10501714,
#        -0.19344969, -0.05784547,  0.12004519, -0.3096397 ,  0.12156403,
#         0.20967844,  0.16143093,  0.05300158,  0.106411  , -0.46143392,
#         0.28650373,  0.12159967,  0.5089349 ,  0.04763117,  0.1252028 ,
#        -0.38854727, -0.25760326,  0.03368601,  0.2512532 ,  0.17360862,
#         0.12806147, -0.31308213,  0.19303307,  0.06275269,  0.47018397,
#         0.10871629, -0.04599661,  0.00591179,  0.07878023, -0.10352803,
#         0.05560298,  0.01066808, -0.1861385 ,  0.20216191, -0.28264514,
#         0.03326981,  0.08932385,  0.33901423, -0.3224104 , -0.11950418,
#        -0.0143122 ,  0.10998341,  0.03704461,  0.14685822,  0.10760647,
#        -0.09933287,  0.0335154 ,  0.26299986,  0.10280067, -0.08525321,
#        -0.16371432,  0.4598582 , -0.04295337,  0.22778124, -0.11349901],
#       dtype=float32)
